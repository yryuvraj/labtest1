# %%
import numpy as np 
import matplotlib.pyplot as mp 
import scipy.signal as ss
import random

global a 
a = []


for i in range(0, 1441):
    x = random.randint(0, 5)
    a.append(x)


def hourly_avg(arr):
    y = 1
    for i in range(0, len(a)-1, 60):
        print("Hourly Average ", y, ": ")
        y+=1
        print(np.mean(a[i]))
    
print("Hourly Averages are : ")
hourly_avg(a)

mp.plot(a)
# Out:
# Hourly Averages are :
# Hourly Average  1 :
# 5.0
# Hourly Average  2 :
# 5.0
# Hourly Average  3 :
# 5.0
# Hourly Average  4 :
# 0.0
# Hourly Average  5 :
# 5.0
# Hourly Average  6 :
# 2.0
# Hourly Average  7 :
# 3.0
# Hourly Average  8 :
# 3.0
# Hourly Average  9 :
# 3.0
# Hourly Average  10 :
# 3.0
# Hourly Average  11 :
# 3.0
# Hourly Average  12 :
# 3.0
# Hourly Average  13 :
# 4.0
# Hourly Average  14 :
# 1.0
# Hourly Average  15 :
# 5.0
# Hourly Average  16 :
# 0.0
# Hourly Average  17 :
# 2.0
# Hourly Average  18 :
# 3.0
# Hourly Average  19 :
# 5.0
# Hourly Average  20 :
# 4.0
# Hourly Average  21 :
# 3.0
# Hourly Average  22 :
# 5.0
# Hourly Average  23 :
# 0.0
# Hourly Average  24 :
# 3.0
